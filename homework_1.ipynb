# %%
print("Меня зовут Алексей и я готов страдать на курсе!")
# Out:
# Меня зовут Алексей и я готов страдать на курсе!

# %% [markdown]
# ## Обо мне
#
# ### Важная информация
# Меня зовут Алексей Первухин, я студент группы МИСТ-25-2, на этом курсе надеюсь узнать много крутого про Python!
#
# ### Где я учился:
# * Лицей Информационных Технологий (г. Новосибирск);
# * Московский Авиационный Институт (Прикладая математика);
# * МИСИС (сейчас)
#
# Вот и всё!

# %% [markdown]
# Остаток от деления 72 на 2:

# %%
77 % 2
# Out:
# 1

# %% [markdown]
# Четное ли число 22?

# %%
if 22 % 2 == 0:
    print('Четное')
else:
    print('Нечетное')
# Out:
# Четное

# %% [markdown]
# 86 в степени 7:

# %%
print(f"86 в степени 7 равно {86**7}")
# Out:
# 86 в степени 7 равно 34792782221696

# %%
print(f"Квадратный корень из 3686400 равен {3686400 ** 0.5}")
# Out:
# Квадратный корень из 3686400 равен 1920.0
